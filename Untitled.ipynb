# %%
import geopandas
import numpy as np
import matplotlib.pyplot as plt
import rasterio as rio
import rasterio.warp as warp
import rasterio.plot as rioPlt

# %%
inFile = rio.open('../processed/Sigma0_20200418/WinsvoldGRD_Sigma0_Subset_Orb_TN_Cal__S1B_IW_GRDH_1SDH_20200418T101605_20200418T101630_021197_028396_5FA1.data/Sigma0_HH_db.img')

# %%
inFile.meta
# Out:
# {'driver': 'ENVI',
#  'dtype': 'float32',
#  'nodata': None,
#  'width': 21232,
#  'height': 19111,
#  'count': 1,
#  'crs': CRS.from_epsg(3413),
#  'transform': Affine(10.0, -0.0, -437632.62616223964,
#         -0.0, -10.0, -2104151.5894930866)}

# %%
array=inFile.read(1)

# %%
plt.imshow(array, cmap='pink')

# %%
plt.hist(array)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-664a379d5939> in <module>()
# ----> 1 plt.hist(array)
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3130                       histtype=histtype, align=align, orientation=orientation,
#    3131                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3132                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3133     finally:
#    3134         ax._hold = washold
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...
