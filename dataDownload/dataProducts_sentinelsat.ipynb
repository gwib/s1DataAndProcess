# %%
from dotenv import load_dotenv
load_dotenv()
import os
from pathlib import Path

from sentinelsat import SentinelAPI, read_geojson, geojson_to_wkt
from datetime import date

# %%
api = SentinelAPI(os.environ.get('sentinelAPI.user'), os.environ.get('sentinelAPI.pass'), 'https://scihub.copernicus.eu/dhus')

# %%
# search by polygon, time, and SciHub query keywords
footprint = geojson_to_wkt(read_geojson(r'./inData/diskoIsland.geojson'))

def findS1Data(fp=footprint,prodType='SLC',ron=171,sliceNo=2):

    products = api.query(fp,
                         platformname='Sentinel-1',
                         producttype=prodType,
                         relativeOrbitNumber=ron,
                         sliceNumber=sliceNo
                         )
    print("Number of products found: "+str(len(products)))
    return products

# %%
pSLC_171 = findS1Data()

# %%
pSLC_90 = findS1Data(ron=90, sliceNo=9)
# Out:
# Querying products: 100%|██████████| 232/232 [00:09<00:00, 24.96 products/s]
# Number of products found: 232

# %%
# check how many products are offline
def checkOfflineProds(products):
    offlineProds = 0
    products_offline = []
    for p in products:
        #print(api.get_product_odata(p))
        product_info = api.get_product_odata(p)
        #print (product_info)
        # extract September data
        #if product_info['date'].month == 9:
        if not product_info['Online']:
            offlineProds +=1
            products_offline.append(p)
            #if product_info['date'] not in online_dates:
            #    online_dates.append(product_info['date'])
    print('Number of products offline:', offlineProds)
                    
    return products_offline

# %%
pSLC90_offline = checkOfflineProds(pSLC_90)
# Out:
# Number of products offline: 168

# %%
def extractMonthData(products, month):
    monthProds = 0
    products_month = []
    for p in products:
        product_info = api.get_product_odata(p)
        # extract September data
        if product_info['date'].month == 9:
            monthProds +=1
            products_month.append(p)
    print('Number of products in this month:', monthProds)
                    
    return products_month

# %%
#prodsSep_171 = extractMonthData(pSLC, 9)

# %%
prodsSep_90 = extractMonthData(pSLC_90, 9)
# Out:
# Number of products in this month: 18

# %%
for p in prodsSep_90:
    print(p['date'])

# %%
#downloadDir = './sepDataGRD'
#Path(downloadDir).mkdir(parents=True, exist_ok=True)

# %%
downloadDir = './data/SLCDataSep90'
Path(downloadDir).mkdir(parents=True, exist_ok=True)

# %%
api.download_all(prodsSep_90, downloadDir)
# Out:
# Downloading: 100%|██████████| 4.57G/4.57G [03:50<00:00, 19.8MB/s]
# MD5 checksumming: 100%|██████████| 4.57G/4.57G [00:12<00:00, 375MB/s]
# Downloading: 100%|██████████| 4.55G/4.55G [04:00<00:00, 18.9MB/s]
# MD5 checksumming: 100%|██████████| 4.55G/4.55G [00:11<00:00, 397MB/s]
# Downloading: 100%|██████████| 4.58G/4.58G [03:50<00:00, 19.9MB/s]
# MD5 checksumming: 100%|██████████| 4.58G/4.58G [00:53<00:00, 85.4MB/s]
# Downloading: 100%|██████████| 4.54G/4.54G [03:37<00:00, 20.9MB/s]
# MD5 checksumming: 100%|██████████| 4.54G/4.54G [00:41<00:00, 110MB/s]
# Downloading: 100%|██████████| 4.56G/4.56G [04:26<00:00, 17.1MB/s]
# MD5 checksumming: 100%|██████████| 4.56G/4.56G [00:46<00:00, 97.7MB/s]
# Product 610749e0-0650-4b7f-90eb-0f3e55fa3cec is not online. Triggering retrieval from long term archive.
# Product 31e873ca-f3ce-4ca5-a7c8-651f698a7e51 is not online. Triggering retrieval from long term archive.
# Requests exceed user quota
# There was an error retrieving 31e873ca-f3ce-4ca5-a7c8-651f698a7e51 from the LTA
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 509, in download
#     self._trigger_offline_retrieval(product_info['url'])
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 456, in _trigger_offline_retrieval
#     raise SentinelAPILTAError('Requests for retrieval from LTA exceed user quota', r)
# sentinelsat.sentinel.SentinelAPILTAError: HTTP status 403 Forbidden: Requests for retrieval from LTA exceed user quota
# Product 89c71caf-09a2-441d-b0b7-60ed290d38bb is not online. Triggering retrieval from long term archive.
# Requests exceed user quota
# There was an error retrieving 89c71caf-09a2-441d-b0b7-60ed290d38bb from the LTA
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 509, in download
#     self._trigger_offline_retrieval(product_info['url'])
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 456, in _trigger_offline_retrieval
#     raise SentinelAPILTAError('Requests for retrieval from LTA exceed user quota', r)
# sentinelsat.sentinel.SentinelAPILTAError: HTTP status 403 Forbidden: Requests for retrieval from LTA exceed user quota
# Product 25275e84-7182-42b1-b80b-579e126835df is not online. Triggering retrieval from long term archive.
# Requests exceed user quota
# There was an error retrieving 25275e84-7182-42b1-b80b-579e126835df from the LTA
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 509, in download
#     self._trigger_offline_retrieval(product_info['url'])
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 456, in _trigger_offline_retrieval
#     raise SentinelAPILTAError('Requests for retrieval from LTA exceed user quota', r)
# sentinelsat.sentinel.SentinelAPILTAError: HTTP status 403 Forbidden: Requests for retrieval from LTA exceed user quota
# Product 3eadbb7c-50e1-4f26-af8a-99f040204a6a is not online. Triggering retrieval from long term archive.
# Requests exceed user quota
# There was an error retrieving 3eadbb7c-50e1-4f26-af8a-99f040204a6a from the LTA
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 509, in download
#     self._trigger_offline_retrieval(product_info['url'])
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 456, in _trigger_offline_retrieval
#     raise SentinelAPILTAError('Requests for retrieval from LTA exceed user quota', r)
# sentinelsat.sentinel.SentinelAPILTAError: HTTP status 403 Forbidden: Requests for retrieval from LTA exceed user quota
# Product 894a95ff-80ed-4fb5-99c3-ad7e7ac58977 is not online. Triggering retrieval from long term archive.
# Requests exceed user quota
# There was an error retrieving 894a95ff-80ed-4fb5-99c3-ad7e7ac58977 from the LTA
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 509, in download
#     self._trigger_offline_retrieval(product_info['url'])
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 456, in _trigger_offline_retrieval
#     raise SentinelAPILTAError('Requests for retrieval from LTA exceed user quota', r)
# sentinelsat.sentinel.SentinelAPILTAError: HTTP status 403 Forbidden: Requests for retrieval from LTA exceed user quota
# Product 00888013-0bd0-4380-a486-e20a26d19e9d is not online. Triggering retrieval from long term archive.
# Requests exceed user quota
# There was an error retrieving 00888013-0bd0-4380-a486-e20a26d19e9d from the LTA
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 509, in download
#     self._trigger_offline_retrieval(product_info['url'])
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 456, in _trigger_offline_retrieval
#     raise SentinelAPILTAError('Requests for retrieval from LTA exceed user quota', r)
# sentinelsat.sentinel.SentinelAPILTAError: HTTP status 403 Forbidden: Requests for retrieval from LTA exceed user quota
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading a0a9f8fc-c1ca-4f0c-8c43-a330507c711c
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading e41e6019-5b45-47c0-822f-31fd1986afe4
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 91baa25d-1eb6-453d-927a-015621da2968
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 2f294d8e-7d7b-418a-a07b-f1f1cb85be9a
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 50e6e69e-b8a1-4f16-8518-6863942142a1
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 50e6e69e-b8a1-4f16-8518-6863942142a1
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 50e6e69e-b8a1-4f16-8518-6863942142a1
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 50e6e69e-b8a1-4f16-8518-6863942142a1
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 50e6e69e-b8a1-4f16-8518-6863942142a1
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
# ...
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# There was an error downloading 032395a1-a3cb-4705-89ae-685824eff3bd
# Traceback (most recent call last):
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 602, in download_all
#     product_info = self.download(product_id, directory_path, checksum)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 493, in download
#     product_info = self.get_product_odata(id)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 427, in get_product_odata
#     _check_scihub_response(response)
#   File "/home/rus/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py", line 1027, in _check_scihub_response
#     raise api_error
# sentinelsat.sentinel.SentinelAPIError: HTTP status 429 Too Many Requests:
# # 429 Too Many Requests
#
# You have sent too many requests in a given amount of time.
# (OrderedDict([('719512de-2557-441c-84b5-aae4d39ee7d8',
#                {'id': '719512de-2557-441c-84b5-aae4d39ee7d8',
#                 'title': 'S1A_IW_SLC__1SDH_20190927T204733_20190927T204800_029212_035162_1CB8',
#                 'size': 4568713987,
#                 'md5': 'AE58E8F42928784397DBADAAC143A799',
#                 'date': datetime.datetime(2019, 9, 27, 20, 47, 33, 230000),
#                 'footprint': 'POLYGON((-55.001762 70.382896,-48.278683 70.911224,-47.449497 69.312630,-53.696293 68.810623,-55.001762 70.382896))',
#                 'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('719512de-2557-441c-84b5-aae4d39ee7d8')/$value",
#                 'Online': True,
#                 'Creation Date': datetime.datetime(2019, 9, 28, 6, 38, 43, 580000),
#                 'Ingestion Date': datetime.datetime(2019, 9, 28, 6, 36, 25, 43000),
#                 'path': './S1A_IW_SLC__1SDH_20190927T204733_20190927T204800_029212_035162_1CB8.zip',
#                 'downloaded_bytes': 4568713987}),
#               ('0aa59de8-9257-4832-9cc3-0369a3d4e00b',
#                {'id': '0aa59de8-9257-4832-9cc3-0369a3d4e00b',
#                 'title': 'S1B_IW_SLC__1SDH_20190921T204651_20190921T204718_018141_02229A_A591',
#                 'size': 4551571327,
#                 'md5': '81482FC91918789D4EBB28EF94E6A407',
#                 'date': datetime.datetime(2019, 9, 21, 20, 46, 51, 127000),
#                 'footprint': 'POLYGON((-55.004890 70.383331,-48.281960 70.911789,-47.452583 69.313446,-53.699318 68.811317,-55.004890 70.383331))',
#                 'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('0aa59de8-9257-4832-9cc3-0369a3d4e00b')/$value",
#                 'Online': True,
#                 'Creation Date': datetime.datetime(2019, 9, 22, 5, 37, 2, 622000),
#                 'Ingestion Date': datetime.datetime(2019, 9, 22, 5, 36, 39, 189000),
#                 'path': './S1B_IW_SLC__1SDH_20190921T204651_20190921T204718_018141_02229A_A591.zip',
#                 'downloaded_bytes': 4551571327}),
#               ('6b331fcc-d748-4d0c-a7ba-c0f9c63dd7df',
#                {'id': '6b331fcc-d748-4d0c-a7ba-c0f9c63dd7df',
#                 'title': 'S1A_IW_SLC__1SDH_20190915T204732_20190915T204759_029037_034B6A_B2C5',
#                 'size': 4579866771,
#                 'md5': '943AAEFC8F1AF7A1A4131B4117584350',
#                 'date': datetime.datetime(2019, 9, 15, 20, 47, 32, 596000),
#                 'footprint': 'POLYGON((-55.001263 70.382912,-48.278557 70.911247,-47.449356 69.312775,-53.695847 68.810753,-55.001263 70.382912))',
#                 'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('6b331fcc-d748-4d0c-a7ba-c0f9c63dd7df')/$value",
#                 'Online': True,
#                 'Creation Date': datetime.datetime(2019, 9, 16, 7, 45, 24, 538000),
#                 'Ingestion Date': datetime.datetime(2019, 9, 16, 7, 39, 11, 268000),
#                 'path': './S1A_IW_SLC__1SDH_20190915T204732_20190915T204759_029037_034B6A_B2C5.zip',
#                 'downloaded_bytes': 4579866771}),
#               ('90787e64-9485-41db-a791-525e39015576',
#                {'id': '90787e64-9485-41db-a791-525e39015576',
#                 'title': 'S1B_IW_SLC__1SDH_20190909T204650_20190909T204717_017966_021D32_F780',
#                 'size': 4543867383,
#                 'md5': '0EA94C35E68C59B538F08632CCDFC9EF',
#                 'date': datetime.datetime(2019, 9, 9, 20, 46, 50, 766000),
#                 'footprint': 'POLYGON((-55.003731 70.382607,-48.281158 70.911011,-47.451954 69.312782,-53.698406 68.810699,-55.003731 70.382607))',
#                 'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('90787e64-9485-41db-a791-525e39015576')/$value",
#                 'Online': True,
#                 'Creation Date': datetime.datetime(2019, 9, 10, 5, 48, 37, 591000),
#                 'Ingestion Date': datetime.datetime(2019, 9, 10, 5, 48, 21, 985000),
#                 'path': './S1B_IW_SLC__1SDH_20190909T204650_20190909T204717_017966_021D32_F780.zip',
#                 'downloaded_bytes': 4543867383}),
#               ('8992eb63-b016-43a0-9816-f49c72976279',
#                {'id': '8992eb63-b016-43a0-9816-f49c72976279',
#                 'title': 'S1A_IW_SLC__1SDH_20190903T204732_20190903T204759_028862_034555_0040',
#                 'size': 4560456150,
#                 'md5': 'D441829BBAE9B44A7DF0A132D465476B',
#                 'date': datetime.datetime(2019, 9, 3, 20, 47, 32, 152000),
#                 'footprint': 'POLYGON((-55.002579 70.382339,-48.280186 70.910713,-47.450970 69.312363,-53.697224 68.810310,-55.002579 70.382339))',
#                 'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8992eb63-b016-43a0-9816-f49c72976279')/$value",
#                 'Online': True,
#                 'Creation Date': datetime.datetime(2019, 9, 4, 3, 23, 37, 981000),
#                 'Ingestion Date': datetime.datetime(2019, 9, 4, 3, 22, 41, 941000),
#                 'path': './S1A_IW_SLC__1SDH_20190903T204732_20190903T204759_028862_034555_0040.zip',
#                 'downloaded_bytes': 4560456150})]),
#  OrderedDict([('610749e0-0650-4b7f-90eb-0f3e55fa3cec',
#                {'id': '610749e0-0650-4b7f-90eb-0f3e55fa3cec',
#                 'title': 'S1B_IW_SLC__1SDH_20180926T204644_20180926T204711_012891_017CE6_5C8D',
#                 'size': 4580725896,
#                 'md5': 'B3A1427C0F74E360813F0B3E7DCE4AF0',
#                 'date': datetime.datetime(2018, 9, 26, 20, 46, 44, 653000),
#                 'footprint': 'POLYGON((-55.027737 70.380913,-48.293724 70.910988,-47.463306 69.312416,-53.720367 68.808784,-55.027737 70.380913))',
#                 'url': "https://scihub.copernicus.eu/dhus/odata/v1/Products('610749e0-0650-4b7f-90eb-0f3e55fa3cec')/$value",
#                 'Online': False,
#                 'Creation Date': datetime.datetime(2018, 9, 27, 5, 25, 20, 924000),
#                 'Ingestion Date': datetime.datetime(2018, 9, 27, 5, 23, 1, 620000),
#                 'path': './S1B_IW_SLC__1SDH_20180926T204644_20180926T204711_012891_017CE6_5C8D.zip',
#                 'downloaded_bytes': 0})]),
#  {'00888013-0bd0-4380-a486-e20a26d19e9d',
#   '032395a1-a3cb-4705-89ae-685824eff3bd',
#   '25275e84-7182-42b1-b80b-579e126835df',
#   '2f294d8e-7d7b-418a-a07b-f1f1cb85be9a',
#   '31e873ca-f3ce-4ca5-a7c8-651f698a7e51',
#   '3eadbb7c-50e1-4f26-af8a-99f040204a6a',
#   '50e6e69e-b8a1-4f16-8518-6863942142a1',
#   '894a95ff-80ed-4fb5-99c3-ad7e7ac58977',
#   '89c71caf-09a2-441d-b0b7-60ed290d38bb',
#   '91baa25d-1eb6-453d-927a-015621da2968',
#   'a0a9f8fc-c1ca-4f0c-8c43-a330507c711c',
#   'e41e6019-5b45-47c0-822f-31fd1986afe4'})

# %%
prodSep_90_offline = checkOfflineProds(prodsSep_90)
# Out:
# Number of products offline: 13

# %%
for p in prodSep_90_offline:
    api.download(p)
# Out:
# Product 610749e0-0650-4b7f-90eb-0f3e55fa3cec is not online. Triggering retrieval from long term archive.
# Product 31e873ca-f3ce-4ca5-a7c8-651f698a7e51 is not online. Triggering retrieval from long term archive.
# Product 89c71caf-09a2-441d-b0b7-60ed290d38bb is not online. Triggering retrieval from long term archive.
# Requests exceed user quota
# ---------------------------------------------------------------------------
# SentinelAPILTAError                       Traceback (most recent call last)
# <ipython-input-25-1294e55e9b05> in <module>
#       1 for p in prodSep_90_offline:
# ----> 2     api.download(p)
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py in download(self, id, directory_path, checksum)
#     507                 'Product %s is not online. Triggering retrieval from long term archive.',
#     508                 product_info['id'])
# --> 509             self._trigger_offline_retrieval(product_info['url'])
#     510             return product_info
#     511
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sentinelsat/sentinel.py in _trigger_offline_retrieval(self, url)
#     454             elif r.status_code == 403:
#     455                 self.logger.error("Requests exceed user quota")
# --> 456                 raise SentinelAPILTAError('Requests for retrieval from LTA exceed user quota', r)
#     457             elif r.status_code == 500:
#     458                 # should not happen
#
# SentinelAPILTAError: HTTP status 403 Forbidden: Requests for retrieval from LTA exceed user quota

# %%
# download products for Sep that are online
#for op in pSLC_online:
#    api.download(op['id'], downloadDir)

# %%
#Download all products 
#api.download_all(products)
